# %%
# %run main.py --model model_AVMixup --m 10 --lambda1 1.0 --lambda2 0.1 --gamma 2.0 --gpu 0 1 2 3 --dataset cifar10
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Model type: Wide-ResNet-34-10
# ==> Building model..
# ...
#   -->	epsilon: 0.03137254901960784
#   -->	alpha: 0.00784313725490196
#   -->	dataset: cifar10
#   -->	GPU number: [0, 1, 2, 3]
#   -->	Epochs (start/end): (0/27)
#   -->	Batch size: 128
#   -->	Adv iterations: 10
#   -->	PGD repeat (eval): 10
# ...
#
# Epoch: 0
#   Loss:  2.3026 ( 2.3026)  Acc (top1):  10.1562 ( 10.1562)  Acc (top5):  47.6562 ( 47.6562)
#   Loss:  2.0747 ( 2.1887)  Acc (top1):  32.8125 ( 21.4844)  Acc (top5):  78.9062 ( 63.2812)
#   Loss:  1.9538 ( 2.1104)  Acc (top1):  34.3750 ( 25.7812)  Acc (top5):  82.0312 ( 69.5312)
#   Loss:  2.0406 ( 2.0929)  Acc (top1):  32.8125 ( 27.5391)  Acc (top5):  90.6250 ( 74.8047)
# Saving..
#   Top1 Acc (clean):  39.0625 ( 38.1310)  Top5 Acc (clean):  87.5000 ( 88.2612)
#   Top1 Acc (AT):  25.7812 ( 25.5609)  Top5 Acc (AT):  78.1250 ( 76.6827)
# ==> Updating the best model..
#
# ...
